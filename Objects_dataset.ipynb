# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !gdown https://drive.google.com/uc?id=1bjFGJu-CvsGYIdQn7VDe56KKe-v3_TE9
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1bjFGJu-CvsGYIdQn7VDe56KKe-v3_TE9
# To: /content/Objects_Dataset.zip
# 100% 919k/919k [00:00<00:00, 121MB/s]

# %%
# !unzip /content/Objects_Dataset.zip;
# Out:
# Archive:  /content/Objects_Dataset.zip
#   inflating: Objects_Dataset_Images/train/dollar_bill/image_0009.jpg
#   inflating: Objects_Dataset_Images/train/dollar_bill/image_0018.jpg
#   inflating: Objects_Dataset_Images/train/motorbike/image_0016.jpg
#   inflating: Objects_Dataset_Images/train/dollar_bill/image_0003.jpg
#   inflating: Objects_Dataset_Images/train/motorbike/image_0010.jpg
#   inflating: Objects_Dataset_Images/train/dollar_bill/image_0013.jpg
#   inflating: Objects_Dataset_Images/train/dollar_bill/image_0007.jpg
#   inflating: Objects_Dataset_Images/train/dollar_bill/image_0015.jpg
#   inflating: Objects_Dataset_Images/train/dollar_bill/image_0012.jpg
#   inflating: Objects_Dataset_Images/train/motorbike/image_0009.jpg
#   inflating: Objects_Dataset_Images/train/motorbike/image_0014.jpg
#   inflating: Objects_Dataset_Images/train/motorbike/image_0003.jpg
#   inflating: Objects_Dataset_Images/train/dollar_bill/image_0010.jpg
# ...

# %%
import matplotlib.pyplot as plt
import os
import numpy as np
from PIL import Image

# Define path to directory containing the images
img_dir = './Objects_Dataset_Images/train/Soccer_Ball'

# Get list of image file names in the directory
img_files = os.listdir(img_dir)

# Set number of rows and columns for subplots
num_rows, num_cols = 2, 3

# Create a figure and subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 6))

# Loop through each image and plot it on a subplot
for i, ax in enumerate(axes.flat):
    # Read in the image file and convert it to a NumPy array
    img_path = os.path.join(img_dir, img_files[i])
    img = np.array(Image.open(img_path))
    
    # Plot the image on the subplot
    ax.imshow(img)
    
    # Set subplot title to the image file name
    ax.set_title(img_files[i])
    
    # Turn off subplot axis labels
    ax.axis('off')
    
# Adjust subplot spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import os
import numpy as np
from PIL import Image

# Define path to directory containing the images
img_dir = './Objects_Dataset_Images/train/accordion'

# Get list of image file names in the directory
img_files = os.listdir(img_dir)

# Set number of rows and columns for subplots
num_rows, num_cols = 2, 3

# Create a figure and subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 6))

# Loop through each image and plot it on a subplot
for i, ax in enumerate(axes.flat):
    # Read in the image file and convert it to a NumPy array
    img_path = os.path.join(img_dir, img_files[i])
    img = np.array(Image.open(img_path))
    
    # Plot the image on the subplot
    ax.imshow(img)
    
    # Set subplot title to the image file name
    ax.set_title(img_files[i])
    
    # Turn off subplot axis labels
    ax.axis('off')
    
# Adjust subplot spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import os
import numpy as np
from PIL import Image

# Define path to directory containing the images
img_dir = './Objects_Dataset_Images/train/dollar_bill'

# Get list of image file names in the directory
img_files = os.listdir(img_dir)

# Set number of rows and columns for subplots
num_rows, num_cols = 2, 3

# Create a figure and subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 6))

# Loop through each image and plot it on a subplot
for i, ax in enumerate(axes.flat):
    # Read in the image file and convert it to a NumPy array
    img_path = os.path.join(img_dir, img_files[i])
    img = np.array(Image.open(img_path))
    
    # Plot the image on the subplot
    ax.imshow(img)
    
    # Set subplot title to the image file name
    ax.set_title(img_files[i])
    
    # Turn off subplot axis labels
    ax.axis('off')
    
# Adjust subplot spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import os
import numpy as np
from PIL import Image

# Define path to directory containing the images
img_dir = './Objects_Dataset_Images/train/motorbike'

# Get list of image file names in the directory
img_files = os.listdir(img_dir)

# Set number of rows and columns for subplots
num_rows, num_cols = 2, 3

# Create a figure and subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 6))

# Loop through each image and plot it on a subplot
for i, ax in enumerate(axes.flat):
    # Read in the image file and convert it to a NumPy array
    img_path = os.path.join(img_dir, img_files[i])
    img = np.array(Image.open(img_path))
    
    # Plot the image on the subplot
    ax.imshow(img)
    
    # Set subplot title to the image file name
    ax.set_title(img_files[i])
    
    # Turn off subplot axis labels
    ax.axis('off')
    
# Adjust subplot spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tqdm.notebook import tqdm
from scipy import ndimage
from scipy.spatial import distance
from sklearn.cluster import KMeans

# %%
def load_images_from_folder(folder):
    images = {}
    for filename in os.listdir(folder):
        category = []
        path = folder + "/" + filename
        print("Path :" ,path)
        for file in tqdm(os.listdir(path)):
          #print("File Name: ",filename)
          img = cv2.imread(os.path.join(path,file))
          if img is not None:
            img = cv2.resize(img, (120, 120))
            category.append(img)
        images[filename] = category
    return images

images = load_images_from_folder('./Objects_Dataset_Images/train')
test = load_images_from_folder('./Objects_Dataset_Images/test')
# Out:
# Path : ./Objects_Dataset_Images/train/accordion
#   0%|          | 0/14 [00:00<?, ?it/s]
# Path : ./Objects_Dataset_Images/train/dollar_bill
#   0%|          | 0/14 [00:00<?, ?it/s]
# Path : ./Objects_Dataset_Images/train/motorbike
#   0%|          | 0/14 [00:00<?, ?it/s]
# Path : ./Objects_Dataset_Images/train/Soccer_Ball
#   0%|          | 0/14 [00:00<?, ?it/s]
# Path : ./Objects_Dataset_Images/test/accordian
#   0%|          | 0/2 [00:00<?, ?it/s]
# Path : ./Objects_Dataset_Images/test/dollar_bill
#   0%|          | 0/2 [00:00<?, ?it/s]
# Path : ./Objects_Dataset_Images/test/motorbike
#   0%|          | 0/2 [00:00<?, ?it/s]
# Path : ./Objects_Dataset_Images/test/Soccer_Ball
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
print("Visualizing data after Train")
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

ax1.axis('off')
# accessing Daisy category in images i.e. train set
ax1.imshow(images.get("dollar_bill")[1])

ax2.axis('off')
# accessing Roses category in images i.e. train set
ax2.imshow(images.get("motorbike")[2])
# Out:
# Visualizing data after Train

# %%
def orb_features(images):
    orb_vectors = {}
    descriptor_list = []
    orb = cv2.ORB_create()
    for key,value in images.items():
        features = []
        for img in tqdm(value):
            kp, des = orb.detectAndCompute(img,None)
            #if kp/descriptor are detected
            if des is not None:
              descriptor_list.extend(des)
            
            features.append(des)
        orb_vectors[key] = features
    return [descriptor_list, orb_vectors]

ORBs = orb_features(images) 
# Takes the descriptor list which is unordered one
descriptor_list = ORBs[0] 
# Takes the ORB features that is seperated class by class for train data
all_bovw_feature = ORBs[1] 
# Takes the ORB features that is seperated class by class for test data

ORBs_test = orb_features(test)
test_descriptor_list = ORBs_test[0]
test_bovw_feature = ORBs_test[1] #directly accessed descriptor_list here using [1] index
# Out:
# ...
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def kmeans(k, descriptor_list):
    kmeans = KMeans(n_clusters = k, n_init=10,verbose=True, max_iter=300)
    print("...")
    kmeans.fit(descriptor_list)
    visual_words = kmeans.cluster_centers_ 
    return visual_words
    
# Takes the central points which is visual words
# It is suggest to make experiments with cluster centroid and observe its imapact on accuracies    
visual_words = kmeans(30, descriptor_list)
# Out:
# ...
# Initialization complete
# Iteration 0, inertia 1474275663.0.
# Iteration 1, inertia 1080519133.777357.
# Iteration 2, inertia 1057404968.2462234.
# Iteration 3, inertia 1048149446.3704422.
# Iteration 4, inertia 1043598556.5372248.
# Iteration 5, inertia 1040853806.7802901.
# Iteration 6, inertia 1038947244.0936043.
# Iteration 7, inertia 1037508159.9898026.
# Iteration 8, inertia 1036289087.2426559.
# Iteration 9, inertia 1035221317.6193558.
# Iteration 10, inertia 1034186477.6551331.
# Iteration 11, inertia 1033292064.7744255.
# Iteration 12, inertia 1032504002.2427263.
# Iteration 13, inertia 1031633165.1914034.
# Iteration 14, inertia 1030847078.243091.
# Iteration 15, inertia 1030042875.5556979.
# Iteration 16, inertia 1029238262.5823087.
# Iteration 17, inertia 1028664412.0699916.
# Iteration 18, inertia 1028121703.1012312.
# Iteration 19, inertia 1027617353.4106938.
# Iteration 20, inertia 1027156780.4736055.
# Iteration 21, inertia 1026805150.9018551.
# ...

# %%
def find_index(image, center):
    count = 0
    ind = 0
    for i in range(len(center)):
        if(i == 0):
           count = distance.euclidean(image, center[i]) 
           #count = L1_dist(image, center[i])
        else:
            dist = distance.euclidean(image, center[i]) 
            #dist = L1_dist(image, center[i])
            if(dist < count):
                ind = i
                count = dist
    return ind

# %%
def image_class(all_bovw, centers):
  dict_feature = {}
  for key,value in all_bovw.items():
      category = []
      for img in tqdm(value):
          histogram = np.zeros(len(centers))
          if img is None:
            continue
          for each_feature in img:
              ind = find_index(each_feature, centers)
              histogram[ind] += 1
          category.append(histogram)
      dict_feature[key] = category
  return dict_feature
    
# Creates histograms for train data    
bovw_train = image_class(all_bovw_feature, visual_words) 
# Creates histograms for test data
bovw_test = image_class(test_bovw_feature, visual_words)
# Out:
# ...
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def knn(images, tests):
    num_test = 0
    correct_predict = 0
    class_based = {}
    
    for test_key, test_val in tests.items():
        class_based[test_key] = [0, 0] # [correct, all]
        for tst in tqdm(test_val):
            predict_start = 0
            #print(test_key)
            minimum = 0
            key = "a" #predicted
            for train_key, train_val in images.items():
                for train in train_val:
                    if(predict_start == 0):
                        minimum = distance.euclidean(tst, train)
                        #minimum = L1_dist(tst,train)
                        key = train_key
                        predict_start += 1
                    else:
                        dist = distance.euclidean(tst, train)
                        #dist = L1_dist(tst,train)
                        if(dist < minimum):
                            minimum = dist
                            key = train_key
            
            if(test_key == key):
                correct_predict += 1
                class_based[test_key][0] += 1
            num_test += 1
            class_based[test_key][1] += 1
            #print(minimum)
    return [num_test, correct_predict, class_based]
    
# Call the knn function    
results_bowl = knn(bovw_train, bovw_test)
# Out:
# ...
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def accuracy(results):
    avg_accuracy = (results[1] / results[0]) * 100
    print("Average accuracy: %" + str(avg_accuracy))
    print("\nClass based accuracies: \n")
    for key,value in results[2].items():
        acc = (value[0] / value[1]) * 100
        print(key + " : %" + str(acc))
        
# Calculates the accuracies and write the results to the console.       
accuracy(results_bowl)
# Out:
# Average accuracy: %62.5
#
# Class based accuracies:
#
# accordian : %0.0
# dollar_bill : %100.0
# motorbike : %50.0
# Soccer_Ball : %100.0

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score

# Create training data and labels
X_train = []
y_train = []

for category, histograms in bovw_train.items():
    for histogram in histograms:
        X_train.append(histogram)
        y_train.append(category)

# Create testing data and labels
X_test = []
y_test = []

for category, histograms in bovw_test.items():
    for histogram in histograms:
        X_test.append(histogram)
        y_test.append(category)

# Train SVM model
clf = svm.SVC(kernel='linear')
clf.fit(X_train, y_train)

# Predict labels for test data
y_pred = clf.predict(X_test)

# Calculate accuracy score
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.625

# %%
from sklearn.metrics import classification_report

# Create list of unique classes
classes = list(set(y_test))

# Create empty list for storing accuracies
accuracies = []

# Loop through each class and calculate accuracy
for c in classes:
    # Create binary labels for current class
    y_true = [1 if label == c else 0 for label in y_test]
    y_pred_class = [1 if label == c else 0 for label in y_pred]
    
    # Calculate accuracy for current class
    accuracy = accuracy_score(y_true, y_pred_class)
    
    # Append accuracy to list of accuracies
    accuracies.append(accuracy)
    
    # Print accuracy for current class
    print(f"Accuracy for class {c}: {accuracy}")

# Calculate overall accuracy
overall_accuracy = sum(accuracies) / len(accuracies)
print(f"\nOverall accuracy: {overall_accuracy}")

# Print classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=['Soccer_Ball', 'accordian', 'motorbike', 'dollar_bill']))
# Out:
# Accuracy for class motorbike: 0.875
# Accuracy for class accordian: 0.75
# Accuracy for class dollar_bill: 0.75
# Accuracy for class Soccer_Ball: 1.0
#
# Overall accuracy: 0.84375
#
# Classification Report:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-3a0f93040828> in <module>
#      28 # Print classification report
#      29 print("\nClassification Report:")
# ---> 30 print(classification_report(y_test, y_pred, target_names=['Soccer_Ball', 'accordian', 'motorbike', 'dollar_bill']))
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2330             )
#    2331         else:
# -> 2332             raise ValueError(
#    2333                 "Number of classes, {0}, does not match size of "
# ...

# %%
def load_images_from_folder(folder):
    """
    This function will take a folder as input and read all the images category vice.
    
    """

    images = {}
    for filename in os.listdir(folder):
        category = []
        path = folder + "/" + filename
        for cat in os.listdir(path):
            img = cv2.imread(path + "/" + cat,0)
            #img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            if img is not None:
                category.append(img)
        images[filename] = category
    return images

# %%
images = load_images_from_folder('./Objects_Dataset_Images/train')
test = load_images_from_folder('./Objects_Dataset_Images/test')

# %%
def sift_features(images):
    """
    This function will create sift features for the images
    """
    class_names = list(images.keys())
    sift_vectors = dict()
    for i in range(len(class_names)):
        sift_vectors[class_names[i]] = i
    
    tags = []
    descriptor_list = []
    sift = cv2.SIFT_create()
    for key,value in images.items():
        features = []
        for img in value:
            kp, des = sift.detectAndCompute(img,None)
           
            descriptor_list.extend(des)
            all_tags = [sift_vectors[key] for _ in range(len(des))]
            tags.extend(all_tags)
        #     features.append(des)
        # sift_vectors[key] = features
    return [descriptor_list, tags]

# %%
sifts = sift_features(images)

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(sifts[0], sifts[1])
# Out:
# SVC()

# %%
import cv2
from sklearn.decomposition import PCA

"""
def make_prediction(image, classifier):
    
    sift = cv2.SIFT_create()
    kp, des = sift.detectAndCompute(image, None)
    if des is not None:
        if des.shape[1] > 128:
            pca = PCA(n_components=128)
            des = pca.fit_transform(des)
        prediction = classifier.predict(des)
        prediction = np.bincount(prediction).argmax()
        return prediction
    else:
        return None
"""
def make_prediction(image_sift, classifier):
    """
    This function will take an image as input and return the prediction made by classifier on that image.
    """
    if image_sift is None or image_sift.ndim != 2:
        return None
    sift = cv2.SIFT_create()
    kp, des = sift.detectAndCompute(image_sift, None)
    if des is None:
        return None
    prediction = classifier.predict(des)
    prediction = np.bincount(prediction).argmax()
    return prediction

# %%
a_test_image = test["Soccer_Ball"][1]
p = make_prediction(a_test_image, svc)
list(test.keys())[p]
# Out:
# 'Soccer_Ball'

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(sifts[0], sifts[1])
# Out:
# RandomForestClassifier()

# %%
a_test_image = test["accordian"][0]
p = make_prediction(a_test_image, rfc)
list(test.keys())[p]
# Out:
# 'accordian'

# %%
a_test_image = test["motorbike"][0]
p = make_prediction(a_test_image, rfc)
list(test.keys())[p]
# Out:
# 'accordian'

# %%
a_test_image = test["dollar_bill"][0]
p = make_prediction(a_test_image, rfc)
list(test.keys())[p]
# Out:
# 'dollar_bill'

# %%
def get_accuracy(classifier, images):
    tags = dict()
    all_classes = list(images.keys())
    for c in range(len(all_classes)):
        tags[all_classes[c]] = c 
    
    original_tags = []
    predicted_tags = []

    sift = cv2.SIFT_create()
    for key, value in images.items():
      features = []
      for img in value:
        if img is None or img.size == 0:
            continue
        if img.ndim == 2:
            img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
        elif img.ndim == 3 and img.shape[2] == 4:
            img = img[..., :3]
        kp, des = sift.detectAndCompute(img, None)
        if des is None:
            continue
        p = make_prediction(des, classifier)
        predicted_tags.append(p)
        original_tags.append(tags[key])

    return original_tags, predicted_tags

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
sift = cv2.SIFT_create()
an_image = test["dollar_bill"][0]
plt.imshow(an_image);
kp, des = sift.detectAndCompute(an_image,None)
pred = list(test.keys())[make_prediction(des, rfc)]
plt.title(f'Original Title: dollar_bill | Predicted Title: {pred}');
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-78-d67d4579d583> in <module>
#       5 plt.imshow(an_image);
#       6 kp, des = sift.detectAndCompute(an_image,None)
# ----> 7 pred = list(test.keys())[make_prediction(des, rfc)]
#       8 plt.title(f'Original Title: dollar_bill | Predicted Title: {pred}');
#
# <ipython-input-63-4eb2c422d217> in make_prediction(image_sift, classifier)
#      24         return None
#      25     sift = cv2.SIFT_create()
# ---> 26     kp, des = sift.detectAndCompute(image_sift, None)
#      27     if des is None:
#      28         return None
#
# error: OpenCV(4.6.0) /io/opencv/modules/features2d/src/sift.dispatch.cpp:477: error: (-5:Bad argument) image is empty or has incorrect depth (!=CV_8U) in function 'detectAndCompute'

# %%
ot, pt = get_accuracy(svc, test)
print("The Accuracy of Support Vector Classifier:")
print("Accuracy:", accuracy_score(ot, pt))
print("R2-Score:", r2_score(ot, pt))

# %%
ot, pt = get_accuracy(rfc, test)
from sklearn.metrics import accuracy_score, r2_score
print("The Accuracy of Random Forest Classifier:")
print("Accuracy:", accuracy_score(ot, pt))
print("R2-Score:", r2_score(ot, pt))
